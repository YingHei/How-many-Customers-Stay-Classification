# %% [markdown]
# # Comparison of Different Classification Methods
# ## Topic: How many Customers Stay

# %% [markdown]
# ### Table of Content:
# 1. [Data Gathering](#first_part)
# 2. [Data Exploration](#second_part)
# 3. [Data Preprocessing](#third_part)
# 4. [Model Building](#fourth_part)
# 5. [Evaluation](#fifth_part)

# %%
# Import packages
import pandas as pd
import numpy as np
from pycaret.classification import *

# %% [markdown]
# ## 1. Data Gathering <a name="first_part"></a>

# %%
train_data = pd.read_csv("train.csv")
train_data.head()
# Out:
#    RowNumber  CustomerId        Surname  CreditScore Geography  Gender  Age  \
# 0          0    15682273          Burns          683    France  Female   38
# 1          1    15694321             Su          619    France  Female   28
# 2          2    15807194  Iweobiegbulam          718     Spain    Male   34
# 3          3    15643966        Goforth          616   Germany    Male   45
# 4          4    15697686        Stewart          787    France  Female   40
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       5  127616.56              1          1               0
# 1       3       0.00              2          1               0
# 2       5  113922.44              2          1               0
# 3       3  143129.41              2          0               1
# 4       6       0.00              2          1               1
#
#    EstimatedSalary  Exited
# 0        123846.07       0
# 1         53394.12       0
# 2         30772.22       0
# 3         64327.26       0
# 4         84151.98       0

# %% [markdown]
# ## 2. Data Exploration <a name="second_part"></a>

# %%
print(f'Dimension of train dataset: {train_data.shape}\n')

print(f'Missing values: \n{train_data.isnull().sum()}')
# Out:
# Dimension of train dataset: (7500, 14)
#
# Missing values:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# ## 3. Data Preprocessing <a name="third_part"></a>

# %%
categorical_features = ['Geography', 'Gender', 'HasCrCard', 'IsActiveMember']
numeric_features = ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'EstimatedSalary']
ignore_features = ['RowNumber', 'CustomerId', 'Surname']

# %%
exit_clf = setup(data = train_data, target='Exited', train_size=0.8, session_id=123, \
                categorical_features=categorical_features, \
                numeric_features=numeric_features, ignore_features=ignore_features)
# Out:
# <style type="text/css">
# #T_5a2c2_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5a2c2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a2c2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5a2c2_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_5a2c2_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_5a2c2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5a2c2_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5a2c2_row1_col1" class="data row1 col1" >Exited</td>
#     </tr>
#     <tr>
#       <th id="T_5a2c2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5a2c2_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_5a2c2_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_5a2c2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5a2c2_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_5a2c2_row3_col1" class="data row3 col1" >0: 0, 1: 1</td>
#     </tr>
#     <tr>
#       <th id="T_5a2c2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5a2c2_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_5a2c2_row4_col1" class="data row4 col1" >(7500, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_5a2c2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5a2c2_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_5a2c2_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5a2c2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5a2c2_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_5a2c2_row6_col1" class="data row6 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_5a2c2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5a2c2_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_5a2c2_row7_col1" class="data row7 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_5a2c2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5a2c2_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_5a2c2_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5a2c2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5a2c2_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_5a2c2_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5a2c2_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5a2c2_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_5a2c2_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_5a2c2_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5a2c2_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_5a2c2_row11_col1" class="data row11 col1" >(6000, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_5a2c2_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5a2c2_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_5a2c2_row12_col1" class="data row12 col1" >(1500, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_5a2c2_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5a2c2_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_5a2c2_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5a2c2_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5a2c2_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_5a2c2_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5a2c2_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5a2c2_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_5a2c2_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_5a2c2_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5a2c2_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_5a2c2_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_5a2c2_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_5a2c2_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_5a2c2_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_5a2c2_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_5a2c2_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_5a2c2_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5a2c2_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_5a2c2_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_5a2c2_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5a2c2_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_5a2c2_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_5a2c2_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_5a2c2_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_5a2c2_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_5a2c2_row21_col1" class="data row21 col1" >bf33</td>
#     </tr>
#     <tr>
#       <th id="T_5a2c2_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_5a2c2_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_5a2c2_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_5a2c2_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_5a2c2_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_5a2c2_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_5a2c2_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_5a2c2_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_5a2c2_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_5a2c2_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_5a2c2_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_5a2c2_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_5a2c2_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_5a2c2_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_5a2c2_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_5a2c2_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_5a2c2_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_5a2c2_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_5a2c2_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_5a2c2_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_5a2c2_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_5a2c2_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_5a2c2_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_5a2c2_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5a2c2_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_5a2c2_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_5a2c2_row30_col1" class="data row30 col1" >None</td>
#     </tr>
#     <

# %%
help(get_config)
# Out:
# Help on function get_config in module pycaret.classification:
#
# get_config(variable: str)
#     This function retrieves the global variables created when initializing the
#     ``setup`` function. Following variables are accessible:
#
#     - X: Transformed dataset (X)
#     - y: Transformed dataset (y)
#     - X_train: Transformed train dataset (X)
#     - X_test: Transformed test/holdout dataset (X)
#     - y_train: Transformed train dataset (y)
#     - y_test: Transformed test/holdout dataset (y)
#     - seed: random state set through session_id
#     - prep_pipe: Transformation pipeline
#     - fold_shuffle_param: shuffle parameter used in Kfolds
#     - n_jobs_param: n_jobs parameter used in model training
#     - html_param: html_param configured through setup
#     - create_model_container: results grid storage container
#     - master_model_container: model storage container
#     - display_container: results display container
#     - exp_name_log: Name of experiment
#     - logging_param: log_experiment param
#     - log_plots_param: log_plots param
#     - USI: Unique session ID parameter
#     - fix_imbalance_param: fix_imbalance param
#     - fix_imbalance_method_param: fix_imbalance_method param
#     - data_before_preprocess: data before preprocessing
#     - target_param: name of target variable
#     - gpu_param: use_gpu param configured through setup
#     - fold_generator: CV splitter configured in fold_strategy
#     - fold_param: fold params defined in the setup
#     - fold_groups_param: fold groups defined in the setup
#     - stratify_param: stratify parameter defined in the setup
#
#
#     Example
#     -------
#     >>> from pycaret.datasets import get_data
#     >>> juice = get_data('juice')
#     >>> from pycaret.classification import *
#     >>> exp_name = setup(data = juice,  target = 'Purchase')
#     >>> X_train = get_config('X_train')
#
#
#     Returns:
#         Global variable

# %%
get_config('X_train')
# Out:
#       CreditScore   Age  Tenure        Balance  NumOfProducts  \
# 28          603.0  39.0     9.0   76769.679688            1.0
# 799         698.0  44.0    10.0  116363.367188            2.0
# 4495        588.0  41.0     2.0  131341.453125            2.0
# 658         537.0  26.0     7.0  106397.750000            1.0
# 1035        509.0  29.0     1.0       0.000000            2.0
# ...           ...   ...     ...            ...            ...
# 5218        685.0  33.0     6.0       0.000000            1.0
# 4060        686.0  25.0     1.0       0.000000            2.0
# 1346        574.0  41.0     1.0       0.000000            2.0
# 3454        715.0  42.0     6.0       0.000000            2.0
# 3582        684.0  34.0     9.0  100628.000000            2.0
#
#       EstimatedSalary  Geography_France  Geography_Germany  Geography_Spain  \
# 28       48224.718750               1.0                0.0              0.0
# 799     198059.156250               0.0                1.0              0.0
# 4495      7034.939941               0.0                1.0              0.0
# 658     103563.226562               1.0                0.0              0.0
# 1035     69113.140625               0.0                0.0              1.0
# ...               ...               ...                ...              ...
# 5218     58458.261719               1.0                0.0              0.0
# 4060     16459.369141               1.0                0.0              0.0
# 1346     70550.000000               1.0                0.0              0.0
# 3454    128745.687500               0.0                0.0              1.0
# 3582    190263.781250               0.0                0.0              1.0
#
#       Gender_Male  HasCrCard_0  IsActiveMember_0
# 28            0.0          1.0               1.0
# 799           1.0          0.0               1.0
# 4495          1.0          1.0               0.0
# 658           1.0          1.0               1.0
# 1035          1.0          0.0               1.0
# ...           ...          ...               ...
# 5218          1.0          0.0               1.0
# 4060          1.0          1.0               0.0
# 1346          1.0          1.0               1.0
# 3454          1.0          0.0               0.0
# 3582          1.0          0.0               0.0
#
# [6000 rows x 12 columns]

# %%
remove_outliers = True

# %%
compare_models(fold = 5)
# Out:
# <style type="text/css">
# #T_28a70_ th {
#   text-align: left;
# }
# #T_28a70_row0_col0, #T_28a70_row0_col3, #T_28a70_row0_col4, #T_28a70_row0_col5, #T_28a70_row1_col0, #T_28a70_row1_col1, #T_28a70_row1_col2, #T_28a70_row1_col3, #T_28a70_row1_col5, #T_28a70_row1_col6, #T_28a70_row1_col7, #T_28a70_row2_col0, #T_28a70_row2_col1, #T_28a70_row2_col2, #T_28a70_row2_col3, #T_28a70_row2_col4, #T_28a70_row2_col6, #T_28a70_row2_col7, #T_28a70_row3_col0, #T_28a70_row3_col1, #T_28a70_row3_col2, #T_28a70_row3_col3, #T_28a70_row3_col4, #T_28a70_row3_col5, #T_28a70_row3_col6, #T_28a70_row3_col7, #T_28a70_row4_col0, #T_28a70_row4_col1, #T_28a70_row4_col2, #T_28a70_row4_col3, #T_28a70_row4_col4, #T_28a70_row4_col5, #T_28a70_row4_col6, #T_28a70_row4_col7, #T_28a70_row5_col0, #T_28a70_row5_col1, #T_28a70_row5_col2, #T_28a70_row5_col3, #T_28a70_row5_col4, #T_28a70_row5_col5, #T_28a70_row5_col6, #T_28a70_row5_col7, #T_28a70_row6_col0, #T_28a70_row6_col1, #T_28a70_row6_col2, #T_28a70_row6_col3, #T_28a70_row6_col4, #T_28a70_row6_col5, #T_28a70_row6_col6, #T_28a70_row6_col7, #T_28a70_row7_col0, #T_28a70_row7_col1, #T_28a70_row7_col2, #T_28a70_row7_col3, #T_28a70_row7_col4, #T_28a70_row7_col5, #T_28a70_row7_col6, #T_28a70_row7_col7, #T_28a70_row8_col0, #T_28a70_row8_col1, #T_28a70_row8_col2, #T_28a70_row8_col3, #T_28a70_row8_col4, #T_28a70_row8_col5, #T_28a70_row8_col6, #T_28a70_row8_col7, #T_28a70_row9_col0, #T_28a70_row9_col1, #T_28a70_row9_col2, #T_28a70_row9_col3, #T_28a70_row9_col4, #T_28a70_row9_col5, #T_28a70_row9_col6, #T_28a70_row9_col7, #T_28a70_row10_col0, #T_28a70_row10_col1, #T_28a70_row10_col2, #T_28a70_row10_col3, #T_28a70_row10_col4, #T_28a70_row10_col5, #T_28a70_row10_col6, #T_28a70_row10_col7, #T_28a70_row11_col0, #T_28a70_row11_col1, #T_28a70_row11_col2, #T_28a70_row11_col3, #T_28a70_row11_col4, #T_28a70_row11_col5, #T_28a70_row11_col6, #T_28a70_row11_col7, #T_28a70_row12_col0, #T_28a70_row12_col1, #T_28a70_row12_col2, #T_28a70_row12_col3, #T_28a70_row12_col4, #T_28a70_row12_col5, #T_28a70_row12_col6, #T_28a70_row12_col7, #T_28a70_row13_col0, #T_28a70_row13_col1, #T_28a70_row13_col2, #T_28a70_row13_col3, #T_28a70_row13_col4, #T_28a70_row13_col5, #T_28a70_row13_col6, #T_28a70_row13_col7, #T_28a70_row14_col0, #T_28a70_row14_col1, #T_28a70_row14_col2, #T_28a70_row14_col4, #T_28a70_row14_col5, #T_28a70_row14_col6, #T_28a70_row14_col7 {
#   text-align: left;
# }
# #T_28a70_row0_col1, #T_28a70_row0_col2, #T_28a70_row0_col6, #T_28a70_row0_col7, #T_28a70_row1_col4, #T_28a70_row2_col5, #T_28a70_row14_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_28a70_row0_col8, #T_28a70_row1_col8, #T_28a70_row2_col8, #T_28a70_row3_col8, #T_28a70_row4_col8, #T_28a70_row5_col8, #T_28a70_row6_col8, #T_28a70_row9_col8, #T_28a70_row10_col8, #T_28a70_row11_col8, #T_28a70_row12_col8, #T_28a70_row13_col8, #T_28a70_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_28a70_row7_col8, #T_28a70_row8_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_28a70_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28a70_level0_row0" class="row_heading level0 row0" >gbc</th>
#       <td id="T_28a70_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_28a70_row0_col1" class="data row0 col1" >0.8593</td>
#       <td id="T_28a70_row0_col2" class="data row0 col2" >0.8646</td>
#       <td id="T_28a70_row0_col3" class="data row0 col3" >0.4738</td>
#       <td id="T_28a70_row0_col4" class="data row0 col4" >0.7531</td>
#       <td id="T_28a70_row0_col5" class="data row0 col5" >0.5814</td>
#       <td id="T_28a70_row0_col6" class="data row0 col6" >0.5022</td>
#       <td id="T_28a70_row0_col7" class="data row0 col7" >0.5218</td>
#       <td id="T_28a70_row0_col8" class="data row0 col8" >0.1500</td>
#     </tr>
#     <tr>
#       <th id="T_28a70_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_28a70_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_28a70_row1_col1" class="data row1 col1" >0.8588</td>
#       <td id="T_28a70_row1_col2" class="data row1 col2" >0.8492</td>
#       <td id="T_28a70_row1_col3" class="data row1 col3" >0.4633</td>
#       <td id="T_28a70_row1_col4" class="data row1 col4" >0.7592</td>
#       <td id="T_28a70_row1_col5" class="data row1 col5" >0.5752</td>
#       <td id="T_28a70_row1_col6" class="data row1 col6" >0.4965</td>
#       <td id="T_28a70_row1_col7" class="data row1 col7" >0.5184</td>
#       <td id="T_28a70_row1_col8" class="data row1 col8" >0.1660</td>
#     </tr>
#     <tr>
#       <th id="T_28a70_level0_row2" class="row_heading level0 row2" >catboost</th>
#       <td id="T_28a70_row2_col0" class="data row2 col0" >CatBoost Classifier</td>
#       <td id="T_28a70_row2_col1" class="data row2 col1" >0.8575</td>
#       <td id="T_28a70_row2_col2" class="data row2 col2" >0.8631</td>
#       <td id="T_28a70_row2_col3" class="data row2 col3" >0.4811</td>
#       <td id="T_28a70_row2_col4" class="data row2 col4" >0.7380</td>
#       <td id="T_28a70_row2_col5" class="data row2 col5" >0.5821</td>
#       <td id="T_28a70_row2_col6" class="data row2 col6" >0.5008</td>
#       <td id="T_28a70_row2_col7" class="data row2 col7" >0.5177</td>
#       <td id="T_28a70_row2_col8" class="data row2 col8" >1.0220</td>
#     </tr>
#     <tr>
#       <th id="T_28a70_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_28a70_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_28a70_row3_col1" class="data row3 col1" >0.8520</td>
#       <td id="T_28a70_row3_col2" class="data row3 col2" >0.8503</td>
#       <td id="T_28a70_row3_col3" class="data row3 col3" >0.4851</td>
#       <td id="T_28a70_row3_col4" class="data row3 col4" >0.7064</td>
#       <td id="T_28a70_row3_col5" class="data row3 col5" >0.5748</td>
#       <td id="T_28a70_row3_col6" class="data row3 col6" >0.4890</td>
#       <td id="T_28a70_row3_col7" class="data row3 col7" >0.5019</td>
#       <td id="T_28a70_row3_col8" class="data row3 col8" >0.4860</td>
#     </tr>
#     <tr>
#       <th id="T_28a70_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_28a70_row4_col0" class="data row4 col0" >Extra Trees Classifier</td>
#       <td id="T_28a70_row4_col1" class="data row4 col1" >0.8517</td>
#       <td id="T_28a70_row4_col2" class="data row4 col2" >0.8414</td>
#       <td id="T_28a70_row4_col3" class="data row4 col3" >0.4375</td>
#       <td id="T_28a70_row4_col4" class="data row4 col4" >0.7381</td>
#       <td id="T_28a70_row4_col5" class="data row4 col5" >0.5490</td>
#       <td id="T_28a70_row4_col6" class="data row4 col6" >0.4672</td>
#       <td id="T_28a70_row4_col7" class="data row4 col7" >0.4903</td>
#       <td id="T_28a70_row4_col8" class="data row4 col8" >0.1400</td>
#     </tr>
#     <tr>
#       <th id="T_28a70_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_28a70_row5_col0" class="data row5 col0" >Ada Boost Classifier</td>
#       <td id="T_28a70_row5_col1" class="data row5 col1" >0.8508</td>
#       <td id="T_28a70_row5_col2" class="data row5 col2" >0.8435</td>
#       <td id="T_28a70_row5_col3" class="data row5 col3" >0.4641</td>
#       <td id="T_28a70_row5_col4" class="data row5 col4" >0.7140</td>
#       <td id="T_28a70_row5_col5" class="data row5 col5" >0.5618</td>
#       <td id="T_28a70_row5_col6" class="data row5 col6" >0.4769</td>
#       <td id="T_28a70_row5_col7" class="data row5 col7" >0.4933</td>
#       <td id="T_28a70_row5_col8" c
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=123, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %% [markdown]
# ### Gradient Boosting Classifier

# %%
gbc = create_model('gbc', fold=5)
print(gbc)
# Out:
# <style type="text/css">
# #T_c227a_row5_col0, #T_c227a_row5_col1, #T_c227a_row5_col2, #T_c227a_row5_col3, #T_c227a_row5_col4, #T_c227a_row5_col5, #T_c227a_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_c227a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c227a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c227a_row0_col0" class="data row0 col0" >0.8658</td>
#       <td id="T_c227a_row0_col1" class="data row0 col1" >0.8751</td>
#       <td id="T_c227a_row0_col2" class="data row0 col2" >0.4980</td>
#       <td id="T_c227a_row0_col3" class="data row0 col3" >0.7688</td>
#       <td id="T_c227a_row0_col4" class="data row0 col4" >0.6044</td>
#       <td id="T_c227a_row0_col5" class="data row0 col5" >0.5280</td>
#       <td id="T_c227a_row0_col6" class="data row0 col6" >0.5461</td>
#     </tr>
#     <tr>
#       <th id="T_c227a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c227a_row1_col0" class="data row1 col0" >0.8600</td>
#       <td id="T_c227a_row1_col1" class="data row1 col1" >0.8675</td>
#       <td id="T_c227a_row1_col2" class="data row1 col2" >0.4677</td>
#       <td id="T_c227a_row1_col3" class="data row1 col3" >0.7632</td>
#       <td id="T_c227a_row1_col4" class="data row1 col4" >0.5800</td>
#       <td id="T_c227a_row1_col5" class="data row1 col5" >0.5017</td>
#       <td id="T_c227a_row1_col6" class="data row1 col6" >0.5234</td>
#     </tr>
#     <tr>
#       <th id="T_c227a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c227a_row2_col0" class="data row2 col0" >0.8608</td>
#       <td id="T_c227a_row2_col1" class="data row2 col1" >0.8689</td>
#       <td id="T_c227a_row2_col2" class="data row2 col2" >0.4919</td>
#       <td id="T_c227a_row2_col3" class="data row2 col3" >0.7485</td>
#       <td id="T_c227a_row2_col4" class="data row2 col4" >0.5937</td>
#       <td id="T_c227a_row2_col5" class="data row2 col5" >0.5140</td>
#       <td id="T_c227a_row2_col6" class="data row2 col6" >0.5305</td>
#     </tr>
#     <tr>
#       <th id="T_c227a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c227a_row3_col0" class="data row3 col0" >0.8467</td>
#       <td id="T_c227a_row3_col1" class="data row3 col1" >0.8529</td>
#       <td id="T_c227a_row3_col2" class="data row3 col2" >0.4234</td>
#       <td id="T_c227a_row3_col3" class="data row3 col3" >0.7192</td>
#       <td id="T_c227a_row3_col4" class="data row3 col4" >0.5330</td>
#       <td id="T_c227a_row3_col5" class="data row3 col5" >0.4485</td>
#       <td id="T_c227a_row3_col6" class="data row3 col6" >0.4711</td>
#     </tr>
#     <tr>
#       <th id="T_c227a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c227a_row4_col0" class="data row4 col0" >0.8633</td>
#       <td id="T_c227a_row4_col1" class="data row4 col1" >0.8586</td>
#       <td id="T_c227a_row4_col2" class="data row4 col2" >0.4879</td>
#       <td id="T_c227a_row4_col3" class="data row4 col3" >0.7658</td>
#       <td id="T_c227a_row4_col4" class="data row4 col4" >0.5961</td>
#       <td id="T_c227a_row4_col5" class="data row4 col5" >0.5186</td>
#       <td id="T_c227a_row4_col6" class="data row4 col6" >0.5377</td>
#     </tr>
#     <tr>
#       <th id="T_c227a_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_c227a_row5_col0" class="data row5 col0" >0.8593</td>
#       <td id="T_c227a_row5_col1" class="data row5 col1" >0.8646</td>
#       <td id="T_c227a_row5_col2" class="data row5 col2" >0.4738</td>
#       <td id="T_c227a_row5_col3" class="data row5 col3" >0.7531</td>
#       <td id="T_c227a_row5_col4" class="data row5 col4" >0.5814</td>
#       <td id="T_c227a_row5_col5" class="data row5 col5" >0.5022</td>
#       <td id="T_c227a_row5_col6" class="data row5 col6" >0.5218</td>
#     </tr>
#     <tr>
#       <th id="T_c227a_level0_row6" class="row_heading level0 row6" >SD</th>
#       <td id="T_c227a_row6_col0" class="data row6 col0" >0.0067</td>
#       <td id="T_c227a_row6_col1" class="data row6 col1" >0.0079</td>
#       <td id="T_c227a_row6_col2" class="data row6 col2" >0.0272</td>
#       <td id="T_c227a_row6_col3" class="data row6 col3" >0.0183</td>
#       <td id="T_c227a_row6_col4" class="data row6 col4" >0.0255</td>
#       <td id="T_c227a_row6_col5" class="data row6 col5" >0.0281</td>
#       <td id="T_c227a_row6_col6" class="data row6 col6" >0.0264</td>
#     </tr>
#   </tbody>
# </table>
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=123, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
# parameters for Gradient Boosting Classifier

gbc_params = {'loss': ,
              'learning_rate': [1, 0.5, 0.25, 0.1, 0.05, 0.01],
              'n_estimators' : [1, 2, 4, 8, 16, 32, 64, 100, 200],
              'max_depth': np.linspace(1, 32, 32, endpoint=True),
              'min_samples_split': np.linspace(0.1, 1.0, 10, endpoint=True),
              'min_samples_leafs' : np.linspace(0.1, 0.5, 5, endpoint=True),
              'weights': 
             }

# %%
tuned_gbc = tune_model(gbc, fold=5, custom_grid = gbc_params,  optimize = 'F1', search_algorithm = 'grid')
tuned_gbc

# %%
plot_model(tuned_gbc)
plot_model(tuned_gbc, plot='confusion_matrix')

# %% [markdown]
# ### Random Forest Classifier

# %%
rf = create_model('rf', fold=5)
print(rf)
# Out:
# <style type="text/css">
# #T_d0075_row5_col0, #T_d0075_row5_col1, #T_d0075_row5_col2, #T_d0075_row5_col3, #T_d0075_row5_col4, #T_d0075_row5_col5, #T_d0075_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_d0075_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0075_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d0075_row0_col0" class="data row0 col0" >0.8725</td>
#       <td id="T_d0075_row0_col1" class="data row0 col1" >0.8631</td>
#       <td id="T_d0075_row0_col2" class="data row0 col2" >0.4980</td>
#       <td id="T_d0075_row0_col3" class="data row0 col3" >0.8092</td>
#       <td id="T_d0075_row0_col4" class="data row0 col4" >0.6165</td>
#       <td id="T_d0075_row0_col5" class="data row0 col5" >0.5452</td>
#       <td id="T_d0075_row0_col6" class="data row0 col6" >0.5684</td>
#     </tr>
#     <tr>
#       <th id="T_d0075_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d0075_row1_col0" class="data row1 col0" >0.8558</td>
#       <td id="T_d0075_row1_col1" class="data row1 col1" >0.8608</td>
#       <td id="T_d0075_row1_col2" class="data row1 col2" >0.4556</td>
#       <td id="T_d0075_row1_col3" class="data row1 col3" >0.7483</td>
#       <td id="T_d0075_row1_col4" class="data row1 col4" >0.5664</td>
#       <td id="T_d0075_row1_col5" class="data row1 col5" >0.4860</td>
#       <td id="T_d0075_row1_col6" class="data row1 col6" >0.5075</td>
#     </tr>
#     <tr>
#       <th id="T_d0075_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d0075_row2_col0" class="data row2 col0" >0.8558</td>
#       <td id="T_d0075_row2_col1" class="data row2 col1" >0.8463</td>
#       <td id="T_d0075_row2_col2" class="data row2 col2" >0.4758</td>
#       <td id="T_d0075_row2_col3" class="data row2 col3" >0.7329</td>
#       <td id="T_d0075_row2_col4" class="data row2 col4" >0.5770</td>
#       <td id="T_d0075_row2_col5" class="data row2 col5" >0.4948</td>
#       <td id="T_d0075_row2_col6" class="data row2 col6" >0.5116</td>
#     </tr>
#     <tr>
#       <th id="T_d0075_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d0075_row3_col0" class="data row3 col0" >0.8492</td>
#       <td id="T_d0075_row3_col1" class="data row3 col1" >0.8251</td>
#       <td id="T_d0075_row3_col2" class="data row3 col2" >0.4153</td>
#       <td id="T_d0075_row3_col3" class="data row3 col3" >0.7410</td>
#       <td id="T_d0075_row3_col4" class="data row3 col4" >0.5323</td>
#       <td id="T_d0075_row3_col5" class="data row3 col5" >0.4508</td>
#       <td id="T_d0075_row3_col6" class="data row3 col6" >0.4776</td>
#     </tr>
#     <tr>
#       <th id="T_d0075_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d0075_row4_col0" class="data row4 col0" >0.8608</td>
#       <td id="T_d0075_row4_col1" class="data row4 col1" >0.8507</td>
#       <td id="T_d0075_row4_col2" class="data row4 col2" >0.4718</td>
#       <td id="T_d0075_row4_col3" class="data row4 col3" >0.7647</td>
#       <td id="T_d0075_row4_col4" class="data row4 col4" >0.5835</td>
#       <td id="T_d0075_row4_col5" class="data row4 col5" >0.5056</td>
#       <td id="T_d0075_row4_col6" class="data row4 col6" >0.5268</td>
#     </tr>
#     <tr>
#       <th id="T_d0075_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_d0075_row5_col0" class="data row5 col0" >0.8588</td>
#       <td id="T_d0075_row5_col1" class="data row5 col1" >0.8492</td>
#       <td id="T_d0075_row5_col2" class="data row5 col2" >0.4633</td>
#       <td id="T_d0075_row5_col3" class="data row5 col3" >0.7592</td>
#       <td id="T_d0075_row5_col4" class="data row5 col4" >0.5752</td>
#       <td id="T_d0075_row5_col5" class="data row5 col5" >0.4965</td>
#       <td id="T_d0075_row5_col6" class="data row5 col6" >0.5184</td>
#     </tr>
#     <tr>
#       <th id="T_d0075_level0_row6" class="row_heading level0 row6" >SD</th>
#       <td id="T_d0075_row6_col0" class="data row6 col0" >0.0078</td>
#       <td id="T_d0075_row6_col1" class="data row6 col1" >0.0135</td>
#       <td id="T_d0075_row6_col2" class="data row6 col2" >0.0275</td>
#       <td id="T_d0075_row6_col3" class="data row6 col3" >0.0271</td>
#       <td id="T_d0075_row6_col4" class="data row6 col4" >0.0272</td>
#       <td id="T_d0075_row6_col5" class="data row6 col5" >0.0305</td>
#       <td id="T_d0075_row6_col6" class="data row6 col6" >0.0296</td>
#     </tr>
#   </tbody>
# </table>
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=123, verbose=0,
#                        warm_start=False)

# %% [markdown]
# ### CatBoost Classifier

# %%
catboost = create_model('catboost', fold=5)
print(catboost)
# Out:
# <style type="text/css">
# #T_a35ca_row5_col0, #T_a35ca_row5_col1, #T_a35ca_row5_col2, #T_a35ca_row5_col3, #T_a35ca_row5_col4, #T_a35ca_row5_col5, #T_a35ca_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_a35ca_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a35ca_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a35ca_row0_col0" class="data row0 col0" >0.8683</td>
#       <td id="T_a35ca_row0_col1" class="data row0 col1" >0.8780</td>
#       <td id="T_a35ca_row0_col2" class="data row0 col2" >0.5101</td>
#       <td id="T_a35ca_row0_col3" class="data row0 col3" >0.7730</td>
#       <td id="T_a35ca_row0_col4" class="data row0 col4" >0.6146</td>
#       <td id="T_a35ca_row0_col5" class="data row0 col5" >0.5392</td>
#       <td id="T_a35ca_row0_col6" class="data row0 col6" >0.5562</td>
#     </tr>
#     <tr>
#       <th id="T_a35ca_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a35ca_row1_col0" class="data row1 col0" >0.8550</td>
#       <td id="T_a35ca_row1_col1" class="data row1 col1" >0.8662</td>
#       <td id="T_a35ca_row1_col2" class="data row1 col2" >0.4718</td>
#       <td id="T_a35ca_row1_col3" class="data row1 col3" >0.7312</td>
#       <td id="T_a35ca_row1_col4" class="data row1 col4" >0.5735</td>
#       <td id="T_a35ca_row1_col5" class="data row1 col5" >0.4910</td>
#       <td id="T_a35ca_row1_col6" class="data row1 col6" >0.5082</td>
#     </tr>
#     <tr>
#       <th id="T_a35ca_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a35ca_row2_col0" class="data row2 col0" >0.8517</td>
#       <td id="T_a35ca_row2_col1" class="data row2 col1" >0.8601</td>
#       <td id="T_a35ca_row2_col2" class="data row2 col2" >0.4960</td>
#       <td id="T_a35ca_row2_col3" class="data row2 col3" >0.6989</td>
#       <td id="T_a35ca_row2_col4" class="data row2 col4" >0.5802</td>
#       <td id="T_a35ca_row2_col5" class="data row2 col5" >0.4932</td>
#       <td id="T_a35ca_row2_col6" class="data row2 col6" >0.5039</td>
#     </tr>
#     <tr>
#       <th id="T_a35ca_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a35ca_row3_col0" class="data row3 col0" >0.8458</td>
#       <td id="T_a35ca_row3_col1" class="data row3 col1" >0.8522</td>
#       <td id="T_a35ca_row3_col2" class="data row3 col2" >0.4315</td>
#       <td id="T_a35ca_row3_col3" class="data row3 col3" >0.7086</td>
#       <td id="T_a35ca_row3_col4" class="data row3 col4" >0.5363</td>
#       <td id="T_a35ca_row3_col5" class="data row3 col5" >0.4504</td>
#       <td id="T_a35ca_row3_col6" class="data row3 col6" >0.4703</td>
#     </tr>
#     <tr>
#       <th id="T_a35ca_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a35ca_row4_col0" class="data row4 col0" >0.8667</td>
#       <td id="T_a35ca_row4_col1" class="data row4 col1" >0.8593</td>
#       <td id="T_a35ca_row4_col2" class="data row4 col2" >0.4960</td>
#       <td id="T_a35ca_row4_col3" class="data row4 col3" >0.7785</td>
#       <td id="T_a35ca_row4_col4" class="data row4 col4" >0.6059</td>
#       <td id="T_a35ca_row4_col5" class="data row4 col5" >0.5304</td>
#       <td id="T_a35ca_row4_col6" class="data row4 col6" >0.5499</td>
#     </tr>
#     <tr>
#       <th id="T_a35ca_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_a35ca_row5_col0" class="data row5 col0" >0.8575</td>
#       <td id="T_a35ca_row5_col1" class="data row5 col1" >0.8631</td>
#       <td id="T_a35ca_row5_col2" class="data row5 col2" >0.4811</td>
#       <td id="T_a35ca_row5_col3" class="data row5 col3" >0.7380</td>
#       <td id="T_a35ca_row5_col4" class="data row5 col4" >0.5821</td>
#       <td id="T_a35ca_row5_col5" class="data row5 col5" >0.5008</td>
#       <td id="T_a35ca_row5_col6" class="data row5 col6" >0.5177</td>
#     </tr>
#     <tr>
#       <th id="T_a35ca_level0_row6" class="row_heading level0 row6" >SD</th>
#       <td id="T_a35ca_row6_col0" class="data row6 col0" >0.0087</td>
#       <td id="T_a35ca_row6_col1" class="data row6 col1" >0.0086</td>
#       <td id="T_a35ca_row6_col2" class="data row6 col2" >0.0277</td>
#       <td id="T_a35ca_row6_col3" class="data row6 col3" >0.0326</td>
#       <td id="T_a35ca_row6_col4" class="data row6 col4" >0.0276</td>
#       <td id="T_a35ca_row6_col5" class="data row6 col5" >0.0318</td>
#       <td id="T_a35ca_row6_col6" class="data row6 col6" >0.0318</td>
#     </tr>
#   </tbody>
# </table>
# <catboost.core.CatBoostClassifier object at 0x7fa4362740a0>
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=5.25107e-14): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=5.2983e-14): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=5.21618e-14): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=5.28794e-14): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=5.34929e-14): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/heifacewong/opt/anaconda3/envs/pycaret_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)

# %%
from datetime import date
save_date = str(date.today().day)+date.today().strftime("%b")+str(date.today().year)

# %%
# Concat all the processed features in training set.

final_feature = np.hstack((credit_score_mm, geo_model, gender_model, age_mm, tenure_mm, balance_mm, num_of_product_mm, 
           np.array(x["HasCrCard"]).reshape(-1,1), np.array(x["IsActiveMember"]).reshape(-1,1), estimated_salary_mm))
final_feature.shape
# Out:
# (7500, 14)

# %%
# Feature selection
gbdt = GradientBoostingClassifier()
gbdt.fit(final_feature, y)
# Out:
# GradientBoostingClassifier()

# %%
gbdt.feature_importances_
# Out:
# array([1.91091078e-02, 7.62158108e-04, 3.15125905e-02, 1.68546143e-04,
#        1.26936023e-03, 2.19411770e-02, 3.69039663e-04, 3.94546224e-01,
#        5.22629665e-03, 8.59283245e-02, 3.04250578e-01, 3.22021375e-04,
#        1.18141417e-01, 1.64531587e-02])

# %%
# Select importance >= 0.01
select_final_feature = final_feature[:, gbdt.feature_importances_>0.01]
select_final_feature.shape
# Out:
# (7500, 8)

# %%
Counter(y)
# Out:
# Counter({0: 5941, 1: 1559})

# %%
# oversample = SMOTE()
# X, y = oversample.fit_resample(final_feature, y)

# %%
smo = SMOTE()
X_smo, y_smo = smo.fit_resample(final_feature, y)

# %%
Counter(y_smo)
# Out:
# Counter({0: 5941, 1: 5941})

# %% [markdown]
# ## 4. Model Building <a name="fourth_part"></a>

# %%
np.mean(cross_val_score(GaussianNB(), X_smo, y_smo, cv=10, scoring="f1"))
# Out:
# 0.6297337971250551

# %%
np.mean(cross_val_score(LogisticRegression(), X_smo, y_smo, cv=10, scoring="f1"))
# Out:
# 0.7016566489735775

# %%
np.mean(cross_val_score(SVC(C=0.8, kernel="linear"), X_smo, y_smo, cv=10, scoring="f1"))

# %%
np.mean(cross_val_score(RandomForestClassifier(n_estimators=180), X_smo, y_smo, cv=10, scoring="f1"))

# %%
np.mean(cross_val_score(GradientBoostingClassifier(n_estimators=150), X_smo, y_smo, cv=10, scoring="f1"))

# %%
np.mean(cross_val_score(MLPClassifier(max_iter=1000, solver="adam"), X_smo, y_smo, cv=10, scoring="f1"))

# %%
# Train model
nb_model = GaussianNB().fit(X_smo, y_smo)

# %%
lr_model = LogisticRegression().fit(X_smo, y_smo)

# %%
rf_model = RandomForestClassifier(n_estimators=180).fit(X_smo, y_smo)

# %%
gbdt_model = GradientBoostingClassifier(n_estimators=180).fit(X_smo, y_smo)

# %%
svm_model = SVC().fit(X_smo, y_smo)

# %%
nn_model = MLPClassifier(max_iter=1000).fit(X_smo, y_smo)

# %%
# Voting classifier
from sklearn.ensemble import VotingClassifier

vote_model = VotingClassifier(estimators=[
    ('rf',RandomForestClassifier(n_estimators=180)),
    ("gbdt",GradientBoostingClassifier(n_estimators=150)),
    ("mlp",MLPClassifier(max_iter=1000))], voting="soft", weights=[1,2,1]).fit(X_smo, y_smo)

print(vote_model)

# %%
# Process test data

test_data = pd.read_csv("assignment-test.csv")
test_data.head()

# %%
test_row = test_data["RowNumber"]
test_data = test_data.drop(["RowNumber", "CustomerId", "Surname"], axis=1)

# %%
test_data.head()

# %%
test_credit = credit_model.transform(np.array(test_data["CreditScore"]).reshape(-1,1).astype("float64"))
test_age = age_model.transform(np.array(test_data["Age"]).reshape(-1,1).astype("float64"))
test_tenure = tenure_model.transform(np.array(test_data["Tenure"]).reshape(-1,1).astype("float64"))
test_balance = balance_model.transform(np.array(test_data["Balance"]).reshape(-1,1).astype("float64"))
test_num_of_product = num_of_product_model.transform(np.array(test_data["NumOfProducts"]).reshape(-1,1).astype("float64"))
test_estimate = estimated_salary_model.transform(np.array(test_data["EstimatedSalary"]).reshape(-1,1).astype("float64"))

test_geo_label = geo_label_model.transform(test_data["Geography"]).reshape(-1,1)
test_geo = geo_model.transform(test_geo_label).toarray()

test_gender_label = gender_label_model.transform(test_data["Gender"]).reshape(-1,1)
test_gender = gender_model.transform(test_gender_label).toarray()

# %%
# Concat all the processed features in testing set.
test_x = np.hstack((test_credit, test_geo, test_gender, test_age, test_tenure, test_balance, test_num_of_product, 
                   np.array(test_data["HasCrCard"]).reshape(-1,1), np.array(test_data["IsActiveMember"]).reshape(-1,1),
                   test_estimate))
# test_x

# %%
# Feature selection
select_test_x = test_x[:, gbdt.feature_importances_>0.01]

# %% [markdown]
# ## 5. Evaluation <a name="fifth_part"></a>

# %%
nb_res = nb_model.predict(test_x)
nb_res = pd.DataFrame({"RowNumber":list(test_row), "Exited":list(nb_res)})
nb_res.to_csv("nb_res.csv", index=None)
# Resulting F1 score:

# %%
lr_res = lr_model.predict(test_x)
lr_res = pd.DataFrame({"RowNumber":list(test_row), "Exited":list(lr_res)})
lr_res.to_csv("lr_res.csv", index=None)
# Resulting F1 score:

# %%
rf_res = rf_model.predict(test_x)
rf_res = pd.DataFrame({"RowNumber":list(test_row), "Exited":list(rf_res)})
rf_res.to_csv("rf_res.csv", index=None)
# Resulting F1 score:

# %%
gbdt_res = gbdt_model.predict(test_x)
gbdt_res = pd.DataFrame({"RowNumber":list(test_row), "Exited":list(gbdt_res)})
gbdt_res.to_csv("gbdt_res.csv", index=None)
# Resulting F1 score:

# %%
svm_res = svm_model.predict(test_x)
svm_res = pd.DataFrame({"RowNumber":list(test_row), "Exited":list(svm_res)})
svm_res.to_csv("svm_res.csv", index=None)
# Resulting F1 score:

# %%
nn_res = nn_model.predict(test_x)
nn_res = pd.DataFrame({"RowNumber":list(test_row), "Exited":list(nn_res)})
nn_res.to_csv("nn_res.csv", index=None)
# Resulting F1 score:

# %%
vote_res = vote_model.predict(test_x)
vote_res = pd.DataFrame({"RowNumber":list(test_row), "Exited":list(vote_res)})
vote_res.to_csv("vote_res.csv", index=None)
# Resulting F1 score:
